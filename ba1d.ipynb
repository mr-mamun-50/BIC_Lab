# %%
s1 = input()
s2 = input()

len1 = len(s1)
len2 = len(s2)
printVals = ""

for i in range(len2 - (len1 + 1)):
  if (s2[i:i+len1] == s1):
    printVals += str(i) + " "

print(printVals)
# Out:
# AGTGACTAG
# ...
# ...
