# %%
givenString = input()
res = ''
for i in givenString:
  if(i == 'A'):
    res = res + 'T'
  elif(i == 'T'):
    res = res + 'A'
  elif(i == 'C'):
    res = res + 'G'
  elif(i == 'G'):
    res = res + 'C'


res = res[::-1]

print(res)
# Out:
# ...
# ...
