# %%
givenString = input()
checkString = input()
count = 0
len1 = len(givenString)
len2 = len(checkString)


for i in range(len1-len2+1):
  if givenString[i:i+len2] == checkString:
      count += 1

print(count)
# Out:
# GCGCG
# GCG
# 2
